# %%
import json
import pandas as pd

# %%
conv_path = './conversations.json'
graph_path = './graph.jsonl'

# %%
with open(conv_path, 'r') as f:
    conversations = json.load(f)

graph = pd.read_json(graph_path, lines=True)

# %%
print(len(conversations[12]['conversations'][0]['value']))
# Out:
# 1878

# %%
for i in range(len(conversations)):
    if len(conversations[i]['conversations'][0]['value']) == 991:
        print(i)
    # print(len(conversations[i]['conversations'][0]['value']))
    # print("======================================================================", i)
    # print(conversations[i]['conversations'][0]['value'])
    # print(conversations[i]['conversations'][1]['value'])
# Out:
# 57

# %%
print(conversations[6]['conversations'][0]['value'])
# Out:
# Given a submodules interconnection graph:
# <graph>
# ,
# nodes: [{'id': 0, 'content': 'clk', 'type': 'input port'}, {'id': 1, 'content': 'rst', 'type': 'input port'}, {'id': 2, 'content': 'clk_out1', 'type': 'output port'}, {'id': 3, 'content': 'clk_out2', 'type': 'output port'}, {'id': 4, 'content': 'clk_out3', 'type': 'output port'}, {'id': 5, 'content': 'div2', 'type': 'submodule'}, {'id': 6, 'content': 'div4', 'type': 'submodule'}, {'id': 7, 'content': 'div8', 'type': 'submodule'}],
# edge_attrs: [],
# connectivity: [[0, 1, 0, 1, 0, 1, 5, 6, 7], [5, 5, 6, 6, 7, 7, 2, 3, 4]]
# , A digital clock divider module designed to take an input clock and a reset signal, producing various divided clock outputs for different subsystems using submodules. Each submodule generates a specific clock frequency by dividing the input clock.
#
# Module name:
#     clock_divider
#
# Input ports:
#     clk: Main clock input.
#     rst: Active low reset signal to initialize the clock dividers.
#
# ...

# %%
#delete index 57
conversations.pop(57)
graph.drop(57, inplace=True)

# %%
for i in range(len(conversations)):
    # if len(conversations[i]['conversations'][0]['value']) == 991:
    #     print(i)
    print(len(conversations[i]['conversations'][0]['value']))
# Out:
# 1808
# 2314
# 2385
# 2015
# 2253
# 2089
# 1690
# 2067
# 1923
# 2395
# 2179
# 1898
# 1878
# 2314
# 2326
# 2138
# 2160
# 2259
# 1970
# 2348
# 2105
# 1748
# 2061
# 1958
# 2483
# 1960
# 2151
# 2213
# 1906
# 2122
# 2278
# 2208
# 2253
# 1774
# 1749
# 1881
# 2218
# 2092
# 2017
# 2252
# 2304
# 1903
# 2425
# 2288
# 2212
# 2250
# 2219
# 2273
# 1829
# 2208
# 2020
# 2348
# 2183
# 2536
# 1877
# 2100
# 2124
# 2248
# 1896
# 1825
# 2473
# 2027
# 2313
# 2146
# 2109
# 2093
# 2056
# 2214
# 1854
# 2361
# 2279
# 1982
# 2011
# 2256
# 2056
# 2128
# 2365
# 2201
# 2141
# 1968
# 2141
# 2017
# 1901
# 1613
# 1789
# 2162
# 2433
# 2078
# 2111
# 1841
# 2243
# 2301
# 2227
# 1886
# 2141
# 1805
# 1819
# 2089
# 2143
# 2394
# 2164
# 2295
# 2467
# 2181
# 2091
# 2087
# 2053
# 2433
# 1992
# 2056
# 2023
# 2034
# 2139
# 2328

# %%
with open(conv_path, 'w') as f:
    json.dump(conversations, f)

graph.to_json(graph_path, orient='records', lines=True)

# %%
with open(conv_path, 'r') as f:
    conversations = json.load(f)
graph = pd.read_json(graph_path, lines=True)

# %%
len(conversations), len(graph)
# Out:
# (114, 114)

# %%
for i in range(len(conversations)):
    # if len(conversations[i]['conversations'][0]['value']) == 991:
    #     print(i)
    print(len(conversations[i]['conversations'][0]['value']))
# Out:
# 1808
# 2314
# 2385
# 2015
# 2253
# 2089
# 1690
# 2067
# 1923
# 2395
# 2179
# 1898
# 1878
# 2314
# 2326
# 2138
# 2160
# 2259
# 1970
# 2348
# 2105
# 1748
# 2061
# 1958
# 2483
# 1960
# 2151
# 2213
# 1906
# 2122
# 2278
# 2208
# 2253
# 1774
# 1749
# 1881
# 2218
# 2092
# 2017
# 2252
# 2304
# 1903
# 2425
# 2288
# 2212
# 2250
# 2219
# 2273
# 1829
# 2208
# 2020
# 2348
# 2183
# 2536
# 1877
# 2100
# 2124
# 2248
# 1896
# 1825
# 2473
# 2027
# 2313
# 2146
# 2109
# 2093
# 2056
# 2214
# 1854
# 2361
# 2279
# 1982
# 2011
# 2256
# 2056
# 2128
# 2365
# 2201
# 2141
# 1968
# 2141
# 2017
# 1901
# 1613
# 1789
# 2162
# 2433
# 2078
# 2111
# 1841
# 2243
# 2301
# 2227
# 1886
# 2141
# 1805
# 1819
# 2089
# 2143
# 2394
# 2164
# 2295
# 2467
# 2181
# 2091
# 2087
# 2053
# 2433
# 1992
# 2056
# 2023
# 2034
# 2139
# 2328

# %%
conversations[6]['conversations'][0]['value']
# Out:
# "Given a submodules interconnection graph: \n<graph>\n, \nnodes: [{'id': 0, 'content': 'clk', 'type': 'input port'}, {'id': 1, 'content': 'rst', 'type': 'input port'}, {'id': 2, 'content': 'clk_out1', 'type': 'output port'}, {'id': 3, 'content': 'clk_out2', 'type': 'output port'}, {'id': 4, 'content': 'clk_out3', 'type': 'output port'}, {'id': 5, 'content': 'div2', 'type': 'submodule'}, {'id': 6, 'content': 'div4', 'type': 'submodule'}, {'id': 7, 'content': 'div8', 'type': 'submodule'}], \nedge_attrs: [], \nconnectivity: [[0, 1, 0, 1, 0, 1, 5, 6, 7], [5, 5, 6, 6, 7, 7, 2, 3, 4]]\n, A digital clock divider module designed to take an input clock and a reset signal, producing various divided clock outputs for different subsystems using submodules. Each submodule generates a specific clock frequency by dividing the input clock.\n\nModule name:\n    clock_divider\n\nInput ports:\n    clk: Main clock input.\n    rst: Active low reset signal to initialize the clock dividers.\n\nOutput ports
# ...

# %%
graph.iloc[6]
# Out:
# nodes           [{'id': 0, 'content': 'clk', 'type': 'input po...
# edge_attrs                                                     []
# connectivity    [[0, 1, 0, 1, 0, 1, 5, 6, 7], [5, 5, 6, 6, 7, ...
# Name: 6, dtype: object
